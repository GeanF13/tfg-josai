# %%
from services.query_classifier_service import QueryClassifierService

# %%
query_classifier = QueryClassifierService()
user_query = "Cómo se llama la asignatura?"
category = query_classifier.classify_query(user_query)

print("Categoría obtenida:", category)
# Out:
# Categoría obtenida: C
